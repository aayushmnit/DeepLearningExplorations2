# %% [markdown]
# ## Introduction

# %% [markdown]
# Encoder-decoder models (also called sequence-to-sequence models) use both parts of the Transformer architecture. At each stage, the attention layers of the encoder can access all the words in the initial sentence, whereas the attention layers of the decoder can only access the words positioned before a given word in the input.
#
# The pretraining of these models can be done using the objectives of encoder or decoder models, but usually involves something a bit more complex. For instance, T5 is pretrained by replacing random spans of text (that can contain several words) with a single mask special word, and the objective is then to predict the text that this mask word replaces.
#
# Sequence-to-sequence models are best suited for tasks revolving around generating new sentences depending on a given input, such as summarization, translation, or generative question answering.
#
# Representatives of this family of models include:
#
# - [BART](https://huggingface.co/transformers/model_doc/bart.html)
# - [mBART](https://huggingface.co/transformers/model_doc/mbart.html)
# - [Marian](https://huggingface.co/transformers/model_doc/marian.html)
# - [T5](https://huggingface.co/transformers/model_doc/t5.html)

# %% [markdown]
# ## How It works?

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# - **Step 1:** Encoder takes a sentence and generates an representation tensor
# - **Step 2:** Decoder take encoder's output alongside the start of the sequence word as i/p and generate a word_1

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# - **Step3:** Once the first word is generated. It autoregress and takes prompt + Word_1 and encoder o/p as i/p to predict Word_2

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# - Step 4: So on now with word_1 and word_2 + starting prompt + encoder encoding to predict Word_3

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ##  Example of Language Translation

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ## When to use Encoders-Decoders?

# %% [markdown]
# - Sequence to sequence tasks; many to many: translation, summarization
# - Weights are not necessarily shared across the encoder and decoder
# - Input distribution different from output distribution

# %% [markdown]
# ### Translation

# %% [markdown]
# Output length is independent of input length in encoder-decoder models

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ### Summarization

# %% [markdown]
# Seq-2-Seq language models handle variable o/p lengths

# %% [markdown]
# ![image.png](attachment:image.png)
