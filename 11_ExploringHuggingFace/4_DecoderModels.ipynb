# %% [markdown]
# ## Decoder Models : Introduction

# %% [markdown]
# Decoder models use only the decoder of a Transformer model. At each stage, for a given word the attention layers can only access the words positioned before it in the sentence. These models are often called auto-regressive models.
#
# The pretraining of decoder models usually revolves around predicting the next word in the sentence.
#
# These models are best suited for tasks involving text generation.
#
# Representatives of this family of models include:
#
# - [CTRL](https://huggingface.co/transformers/model_doc/ctrl.html)
# - [GPT](https://huggingface.co/transformers/model_doc/gpt.html)
# - [GPT-2](https://huggingface.co/transformers/model_doc/gpt2.html)
# - [Transformer XL](https://huggingface.co/transformers/model_doc/transformerxl.html)

# %% [markdown]
# ## Decoder

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# The decoder outputs the numerical representation from an initial sequence -

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# This feature tensor is a made up of vector of values for each word of the initial sequence

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# How decoder differs from encoders is principally in their self-attention mechanism. Decoder uses masked self-attention. Words can only see the words on their left side, the right side is hidden/masked. So in the above example, word "to" representation will only be effected by "Welcome" and not by "NYC". Decoders are not bi-directional and have access to single context.

# %% [markdown]
# ## When should we use decoders?

# %% [markdown]
# - Unidiretional: access to their left(or right) context
# - Great at causal tasks; generating sequences
# - NLG: Natural language generation
# - Example of decoders: GPT-2, GPT Neo

# %% [markdown]
# ### Causal Language Modeling
# Guessing the next word in a sentence

# %% [markdown]
# Decoders with their uni-directional context, are good at generating words given a context. It's an AutoRegressive model i.e. it uses it previous outputs as input to predict the next output.

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# GPT 2 have a maximum context size of 1024.
